# %%
import pandas as pd
df1=pd.read_csv("titanic.csv")
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print(df1['Embarked'].unique())
# print(df1['job'].unique())
# print(df1['degree'].unique())
# df1.isna().sum()
# Out:
# ['S' 'C' 'Q' nan]

# %%
agem=df1['Age'].mean()
agem
# Out:
# 29.69911764705882

# %%
df1['Age'].fillna(agem,inplace=True)
df1['Age'].isna().sum()
# Out:
# 0

# %%
df1=df1.drop(columns=['PassengerId','Name','Ticket','Cabin','Embarked','SibSp','Parch'])
df1
# Out:
#      Survived  Pclass     Sex        Age     Fare
# 0           0       3    male  22.000000   7.2500
# 1           1       1  female  38.000000  71.2833
# 2           1       3  female  26.000000   7.9250
# 3           1       1  female  35.000000  53.1000
# 4           0       3    male  35.000000   8.0500
# ..        ...     ...     ...        ...      ...
# 886         0       2    male  27.000000  13.0000
# 887         1       1  female  19.000000  30.0000
# 888         0       3  female  29.699118  23.4500
# 889         1       1    male  26.000000  30.0000
# 890         0       3    male  32.000000   7.7500
#
# [891 rows x 5 columns]

# %%
df=pd.get_dummies(df1,dtype=int)
df
# Out:
#      Survived  Pclass        Age     Fare  Sex_female  Sex_male
# 0           0       3  22.000000   7.2500           0         1
# 1           1       1  38.000000  71.2833           1         0
# 2           1       3  26.000000   7.9250           1         0
# 3           1       1  35.000000  53.1000           1         0
# 4           0       3  35.000000   8.0500           0         1
# ..        ...     ...        ...      ...         ...       ...
# 886         0       2  27.000000  13.0000           0         1
# 887         1       1  19.000000  30.0000           1         0
# 888         0       3  29.699118  23.4500           1         0
# 889         1       1  26.000000  30.0000           0         1
# 890         0       3  32.000000   7.7500           0         1
#
# [891 rows x 6 columns]

# %%
Y=df['Survived']
Y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
X=df.drop(columns=['Survived'])
X
# Out:
#      Pclass        Age     Fare  Sex_female  Sex_male
# 0         3  22.000000   7.2500           0         1
# 1         1  38.000000  71.2833           1         0
# 2         3  26.000000   7.9250           1         0
# 3         1  35.000000  53.1000           1         0
# 4         3  35.000000   8.0500           0         1
# ..      ...        ...      ...         ...       ...
# 886       2  27.000000  13.0000           0         1
# 887       1  19.000000  30.0000           1         0
# 888       3  29.699118  23.4500           1         0
# 889       1  26.000000  30.0000           0         1
# 890       3  32.000000   7.7500           0         1
#
# [891 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.20)
print(X_train.shape,X_test.shape,Y_train.shape,Y_test.shape)
# Out:
# (712, 5) (179, 5) (712,) (179,)

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()

# %%
model.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
ans=model.predict([[X_test]])
# Out:
# D:\installed_files\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 model.predict([[X_test]])
#
# File D:\installed_files\Python\Lib\site-packages\sklearn\tree\_classes.py:529, in BaseDecisionTree.predict(self, X, check_input)
#     506 """Predict class or regression value for X.
#     507
#     508 For a classification model, the predicted class for each sample in X is
#    (...)
#     526     The predicted classes, or the predict values.
#     527 """
#     528 check_is_fitted(self)
# --> 529 X = self._validate_X_predict(X, check_input)
#     530 proba = self.tree_.predict(X)
#     531 n_samples = X.shape[0]
#
# ...
